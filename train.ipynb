# %%
# !python train_cvae_connectomes.py
# Out:
# Using device: cuda
# Loading data for 352 subjects...
# CVAE Train set: 226, CVAE Validation set: 56, CVAE Test set (unused by CVAE directly): 70
#
# --- Training CVAE (on AD, CN, Other) ---
# CVAE Epoch 1/500: Beta_KL: 0.0110 LR: 1.0e-04
#   Train Loss: 4767.3982 (Recon: 4766.3221, KL: 97.9134)
#   Val Loss  : 3945.4786 (Recon: 3945.4585, KL: 1.8319)
# Validation loss decreased (inf --> 3945.478638). Saving model ...
# Validation loss decreased (3945.478638 --> 3921.080688). Saving model ...
# Validation loss decreased (3921.080688 --> 3844.593994). Saving model ...
# Validation loss decreased (3844.593994 --> 3725.180420). Saving model ...
# Validation loss decreased (3725.180420 --> 3645.082153). Saving model ...
# Validation loss decreased (3645.082153 --> 3575.995239). Saving model ...
# Validation loss decreased (3575.995239 --> 3435.998413). Saving model ...
# Validation loss decreased (3435.998413 --> 3252.364014). Saving model ...
# ...
