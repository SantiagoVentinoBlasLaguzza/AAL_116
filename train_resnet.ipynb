# %%
# !python resnet.py
# Out:
# Using device: cuda
# Loading data for 352 subjects...
# CVAE Train set: 212, CVAE Validation set: 56, Test set: 84
# ResNet Encoder Layer Shapes:
#   After Initial Conv/Pool: (64, 29, 29)
#   After Stage 2: (256, 29, 29)
#   After Stage 3: (512, 15, 15)
#   After Stage 4: (1024, 8, 8)
# reconstruction shape: torch.Size([1, 3, 116, 116])
#
# --- Training CVAE with ResNet Encoder (on AD, CN, Other) ---
# CVAE Epoch 1/200: Beta_KL: 0.0143 LR: 1.0e-04
#   Train Loss: 4586.7405 (Recon: 4586.5798, KL: 11.2273)
#   Val Loss  : 3276.2671 (Recon: 3276.2539, KL: 0.9185)
# Validation loss decreased (inf --> 3276.267090). Saving model ...
# Validation loss decreased (3276.267090 --> 2916.486816). Saving model ...
# Validation loss decreased (2916.486816 --> 2488.470215). Saving model ...
# Validation loss decreased (2488.470215 --> 2190.377808). Saving model ...
# Validation loss decreased (2190.377808 --> 2094.861816). Saving model ...
# ...
