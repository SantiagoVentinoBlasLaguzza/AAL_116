# %%
# !python resnet_full.py
# Out:
# 2025-05-16 21:14:41,504 - INFO - Using device: cuda
# 2025-05-16 21:14:41,505 - INFO - --- Initializing Datasets ---
# 2025-05-16 21:14:41,576 - INFO - Successfully performed stratified splits.
# 2025-05-16 21:14:41,576 - INFO - Creating dataset (fit_scalers=True) with 224 files...
# 2025-05-16 21:14:41,675 - INFO - Creating dataset (fit_scalers=False) with 57 files...
# 2025-05-16 21:14:41,695 - INFO - Creating dataset (fit_scalers=False) with 71 files...
# 2025-05-16 21:14:41,719 - INFO - CVAE Train set: 224, CVAE Validation set: 57, Final Test set: 71
# 2025-05-16 21:14:42,407 - INFO -
# --- Training CVAE with ResNet Encoder (on AD, CN, Other) ---
# 2025-05-16 21:14:43,233 - INFO - CVAE Epoch 1/200: Beta_KL: 0.0502 Capacity_C: 0.31 LR: 9.9e-05
#   Train Loss: 5851.8717 (Recon: 5851.5400, KL: 6.9167)
#   Val Loss  : 3341.1127 (Recon: 3341.1013, KL: 0.5386)
# 2025-05-16 21:14:43,233 - INFO - Validation loss decreased (inf --> 3341.112671). Saving model ...
# ...
